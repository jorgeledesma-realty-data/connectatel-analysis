# %% [markdown]
# ¡Hola Jorge! Espero estés bien.
#
# Mi nombre es **Gina Buvoli**. Un gusto conocerte, seré tu revisora en este proyecto.
#
# A continuación, te comparto un poco sobre la modalidad de revisión que vamos a usar:
#
# Cuando encuentre un error por primera vez, simplemente lo señalaré y dejaré que lo detectes y corrijas por tu cuenta. Además, a lo largo del proyecto iré haciendo algunas observaciones para mejorar tu código, así como comentarios sobre tus conclusiones o percepciones sobre el tema.
#
# Si en algún momento no logras resolver la tarea, en la siguiente iteración te daré una pista más precisa, junto con algunos ejemplos prácticos. También estoy abierta a responder cualquier duda que tengas.
#
# Encontrarás mis comentarios a continuación: por favor, no los muevas, modifiques ni elimines.
#
# ---
#
# ### Formato de Comentarios
#
# Revisaré cuidadosamente cada implementación en tu notebook para asegurar que cumpla con los requisitos y te daré comentarios de acuerdo al siguiente formato:
#
# <div class="alert alert-block alert-success">
# <b>Comentario de la revisora [#° iteración]</b> <a class="tocSkip"></a><br>
# <b>Éxito ✅</b><br>
# ¡Excelente trabajo! Esta parte está bien implementada y contribuye significativamente al análisis. Continúa aplicando estas buenas prácticas en futuras secciones.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario de la revisora [#° iteración]</b> <a class="tocSkip"></a><br>
# <b>Atención ⚠️</b><br>
# El código es correcto, pero hay una recomendación de mejora. No bloquea la aprobación, pero vale la pena ajustarlo.
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario de la revisora [#° iteración]</b> <a class="tocSkip"></a><br>
# <b>A resolver 🔴</b><br>
# Aquí hay un error que es necesario corregir para aprobar. Por favor revisa este punto antes de volver a enviar.
# </div>
#
# ---
#
# En cada revisión recibirás un **Comentario General** que resume los aspectos positivos, las áreas de mejora y los próximos pasos.
#
# También puedes responderme copiando el siguiente bloque si tienes alguna duda:
#
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante [#° iteración]</b> <a class="tocSkip"></a>
#
# Aquí puedes escribir tu respuesta o pregunta.
# </div>
#
# **¡Empecemos!** 🚀

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Review General. (Iteración 1)</b> <a class="tocSkip"></a>
#
# ¡Hola Jorge!
#
# Tu análisis es uno de los más sólidos y completos. Quiero destacar tres aspectos que sobresalen claramente:
#
# - Tu verificación MAR en el Paso 3.2 es muy completa: calculas tanto el conteo como la proporción de nulos por tipo para <code>duration</code> y <code>length</code>, y aplicaste <code>.fillna(0)</code> de forma proactiva después del merge, con un comentario explicando exactamente por qué.
# - En el Paso 5, identificas correctamente que el plan Básico aparece con más volumen absoluto simplemente porque tiene más usuarios — no por un patrón de consumo distinto — una distinción estadística que muy pocos proyectos hicieron.
# - Tu análisis ejecutivo del Paso 7 incluye una celda de verificación dedicada que reconfirma en código cada cifra antes de escribirla en el texto. No hay ningún hallazgo inventado — todo está respaldado por tu propio análisis.
#
# Sin embargo, tu proyecto queda **rechazado** por un solo motivo: el repositorio de GitHub no fue entregado. El placeholder (<code>LINK a tu repo aquí</code>) quedó sin reemplazar, y no hay ninguna URL en ningún lugar del notebook.
#
# Por favor, crea el repositorio con tu notebook y un <code>README.md</code>, comparte el enlace y vuelve a enviar. El resto de tu proyecto ya está en un nivel excelente.
# </div>

# %% [markdown]
# # Análisis ConnectaTel
#
# Como **analista de datos**, tu objetivo es evaluar el **comportamiento de los clientes** de una empresa de telecomunicaciones en Latinoamérica, ConnectaTel.
#
# Trabajaremos con información registrada **hasta el año 2024**, lo cual permitirá analizar el comportamiento del negocio dentro de ese periodo.
#
# Para ello trabajarás con tres datasets:
#
# - **plans.csv** → información de los planes actuales (precio, minutos incluidos, GB incluidos, costo por extra)
# - **users.csv** → información de los clientes (edad, ciudad, fecha de registro, plan, churn)
# - **usage.csv** → detalle del **uso real** de los servicios (llamadas y mensajes)
#
# Deberás **explorar**, **limpiar** y **analizar** estos datos para construir un **perfil estadístico** de los clientes, detectar **comportamientos atípicos** y crear **segmentos de clientes**.
#
# Este análisis te permitirá **identificar patrones de consumo**, **diseñar estrategias de retención** y **sugerir mejoras en los planes** ofrecidos por la empresa.
#
# > 💡 Antes de empezar, recuerda pensar de forma **programática**: ¿qué pasos necesitas? ¿En qué orden? ¿Qué quieres medir y por qué?

# %% [markdown]
# ---
# ## 🧩 Paso 1: Cargar y explorar
#
# Antes de limpiar o combinar los datos, es necesario **familiarizarte con la estructura de los tres datasets**.
# En esta etapa, validarás que los archivos se carguen correctamente, conocerás sus columnas y tipos de datos, y detectarás posibles inconsistencias.
#
# ### 1.1 Carga de datos y vista rápida
#
# **🎯 Objetivo:**
# Tener los **3 datasets listos en memoria**, entender su contenido y realizar una revisión preliminar.
#
# **Instrucciones:**
# - Importa las librerías necesarias (por ejemplo `pandas`, `seaborn`, `matplotlib.pyplot`)
# - Carga los archivos CSV usando `pd.read_csv()`:
#   - **`/datasets/plans.csv`**
#   - **`/datasets/users_latam.csv`**
#   - **`/datasets/usage.csv`**
# - Guarda los DataFrames en las variables: `plans`, `users`, `usage`.
# - Muestra las primeras filas de cada DataFrame usando `.head()`.

# %%
# importar librerías
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# cargar archivos
plans = pd.read_csv('/datasets/plans.csv')
users = pd.read_csv('/datasets/users_latam.csv')
usage = pd.read_csv('/datasets/usage.csv')

# %%
# mostrar las primeras 5 filas de plans
plans.head()
# Out:
#   plan_name  messages_included  gb_per_month  minutes_included  \
# 0    Basico                100             5               100
# 1   Premium                500            20               600
#
#    usd_monthly_pay  usd_per_gb  usd_per_message  usd_per_minute
# 0               12         1.2             0.08            0.10
# 1               25         1.0             0.05            0.07

# %%
# mostrar las primeras 5 filas de users
users.head()
# Out:
#    user_id first_name last_name  age      city                       reg_date  \
# 0    10000     Carlos    Garcia   38  Medellín  2022-01-01 00:00:00.000000000
# 1    10001      Mateo    Torres   53         ?  2022-01-01 06:34:17.914478619
# 2    10002      Sofia   Ramirez   57      CDMX  2022-01-01 13:08:35.828957239
# 3    10003      Mateo   Ramirez   69    Bogotá  2022-01-01 19:42:53.743435858
# 4    10004      Mateo    Torres   63       GDL  2022-01-02 02:17:11.657914478
#
#       plan churn_date
# 0   Basico        NaN
# 1   Basico        NaN
# 2   Basico        NaN
# 3  Premium        NaN
# 4   Basico        NaN

# %%
# mostrar las primeras 5 filas de usage
usage.head()
# Out:
#    id  user_id  type                           date  duration  length
# 0   1    10332  call  2024-01-01 00:00:00.000000000      0.09     NaN
# 1   2    11458  text  2024-01-01 00:06:30.969774244       NaN    39.0
# 2   3    11777  text  2024-01-01 00:13:01.939548488       NaN    36.0
# 3   4    10682  call  2024-01-01 00:19:32.909322733      1.53     NaN
# 4   5    12742  call  2024-01-01 00:26:03.879096977      4.84     NaN

# %% [markdown]
# **Tip:** Si no usas `print()` la tabla se vera mejor.

# %% [markdown]
# ### 1.2 Exploración de la estructura de los datasets
#
# **🎯 Objetivo:**
# Conocer la **estructura de cada dataset**, revisar cuántas filas y columnas tienen, identificar los **tipos de datos** de cada columna y detectar posibles **inconsistencias o valores nulos** antes de iniciar el análisis.
#
# **Instrucciones:**
# - Revisa el **número de filas y columnas** de cada dataset usando `.shape`.
# - Usa `.info()` en cada DataFrame para obtener un **resumen completo** de columnas, tipos de datos y valores no nulos.

# %%
# revisar el número de filas y columnas de cada dataset
print("plans", plans.shape)
print("users", users.shape)
print("usage", usage.shape)
# Out:
# plans (2, 8)
# users (4000, 8)
# usage (40000, 6)

# %%
# inspección de plans con .info()
plans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   plan_name          2 non-null      object
#  1   messages_included  2 non-null      int64
#  2   gb_per_month       2 non-null      int64
#  3   minutes_included   2 non-null      int64
#  4   usd_monthly_pay    2 non-null      int64
#  5   usd_per_gb         2 non-null      float64
#  6   usd_per_message    2 non-null      float64
#  7   usd_per_minute     2 non-null      float64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 256.0+ bytes

# %%
# inspección de users con .info()
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     4000 non-null   int64
#  1   first_name  4000 non-null   object
#  2   last_name   4000 non-null   object
#  3   age         4000 non-null   int64
#  4   city        3531 non-null   object
#  5   reg_date    4000 non-null   object
#  6   plan        4000 non-null   object
#  7   churn_date  466 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 250.1+ KB

# %%
# inspección de usage con .info()
usage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        40000 non-null  int64
#  1   user_id   40000 non-null  int64
#  2   type      40000 non-null  object
#  3   date      39950 non-null  object
#  4   duration  17924 non-null  float64
#  5   length    22104 non-null  float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 1.8+ MB

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de la revisora. (Iteración 1)</b> <a class="tocSkip"></a>
# ¡Buen inicio! Importaste las librerías necesarias, cargaste los 3 datasets correctamente con <code>users_latam.csv</code>, y exploraste la estructura con <code>.shape</code> e <code>.info()</code>. Todo listo para el análisis de calidad.
# </div>

# %% [markdown]
# ---
#
# ## 🧩Paso 2: Identificación de problemas de calidad de datos
#
# ### 2.1 Revisión de valores nulos
#
# **🎯 Objetivo:**
# Detectar la presencia y magnitud de valores faltantes para evaluar si afectan el análisis o requieren imputación/eliminación.
#
# **Instrucciones:**
# - Cuenta valores nulos por columna para cada dataset.
# - Calcula la proporción de nulos por columna para cada dataset.
#
# El dataset `plans` solamente tiene 2 renglones y se puede observar que no tiene ausentes, por ello no necesita exploración adicional.
#
# <br>
# <details>
# <summary>Haz clic para ver la pista</summary>
# Usa `.isna().sum()` para contar valores nulos y usa `.isna().mean()` para calcular la proporción.

# %%
# cantidad de nulos para users
print("Valores nulos en plans:")
print(plans.isna().sum())

print("Valores nulos en users:")
print(users.isna().sum())

print("Valores nulos en usage:")
print(usage.isna().sum())
# Out:
# Valores nulos en plans:
# plan_name            0
# messages_included    0
# gb_per_month         0
# minutes_included     0
# usd_monthly_pay      0
# usd_per_gb           0
# usd_per_message      0
# usd_per_minute       0
# dtype: int64
# Valores nulos en users:
# user_id          0
# first_name       0
# last_name        0
# age              0
# city           469
# reg_date         0
# plan             0
# churn_date    3534
# dtype: int64
# Valores nulos en usage:
# id              0
# user_id         0
# type            0
# date           50
# duration    22076
# length      17896
# dtype: int64

# %%
# cantidad de nulos para usage
print("Proporción de nulos en plans:")
print(plans.isna().mean())

print("Proporción de nulos en users:")
print(users.isna().mean())

print("Proporción de nulos en usage:")
print(usage.isna().mean())
# Out:
# Proporción de nulos en plans:
# plan_name            0.0
# messages_included    0.0
# gb_per_month         0.0
# minutes_included     0.0
# usd_monthly_pay      0.0
# usd_per_gb           0.0
# usd_per_message      0.0
# usd_per_minute       0.0
# dtype: float64
# Proporción de nulos en users:
# user_id       0.00000
# first_name    0.00000
# last_name     0.00000
# age           0.00000
# city          0.11725
# reg_date      0.00000
# plan          0.00000
# churn_date    0.88350
# dtype: float64
# Proporción de nulos en usage:
# id          0.00000
# user_id     0.00000
# type        0.00000
# date        0.00125
# duration    0.55190
# length      0.44740
# dtype: float64

# %% [markdown]
# ✍️ **Comentario**: Haz doble clic en este bloque y escribe tu diagnóstico al final del bloque. Incluye qué ves y que acción recomendarías para cada caso.
#
# 💡 **Nota:** Justifica tus decisiones brevemente (1 línea por caso).
# * Hint:
#  - Si una columna tiene **más del 80–90% de nulos**, normalmente se **ignora o elimina**.
#  - Si tiene **entre 5% y 30%**, generalmente se **investiga para imputar o dejar como nulos**.
#  - Si es **menor al 5%**, suele ser un caso simple de imputación o dejar como nulos.
#
#  ---
#
# **Valores nulos**
# - ¿Qué columnas tienen valores faltantes y en qué proporción?
# - Indica qué harías: ¿imputar, eliminar, ignorar?
#
# Diagnóstico: El dataset plans no presenta valores nulos (0%), por lo que no requiere tratamiento. En users, la columna city tiene 11.73% de valores nulos, por lo que se recomienda investigar la causa y, si es necesario, imputarlos o conservarlos como valores desconocidos. La columna churn_date tiene 88.35% de valores nulos; debido a que supera el 80–90%, normalmente podría ignorarse o eliminarse, pero en este caso no se recomienda eliminarla, ya que la ausencia de fecha puede representar que el cliente continúa activo y es relevante para analizar churn.
#
# En usage, la columna date tiene solo 0.125% de valores nulos, por lo que se puede investigar y, si es necesario, eliminar esos pocos registros o imputarlos si existe una regla clara. Las columnas duration (55.19%) y length (44.74%) presentan una proporción alta de valores nulos. Sin embargo, estos faltantes deben analizarse según el tipo de uso (type), ya que una llamada utiliza duration y un mensaje utiliza length; por lo tanto, un valor nulo en la variable que no corresponde al tipo de registro puede ser esperado y no necesariamente un error.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de la revisora. (Iteración 1)</b> <a class="tocSkip"></a>
# Diagnóstico de nulos excelente, cubriendo los tres datasets con cifras exactas y decisiones bien justificadas. Destaca el buen razonamiento sobre <code>duration</code>/<code>length</code>: en lugar de decidir de inmediato, correctamente pospones la acción hasta verificar si dependen de <code>type</code>.
# </div>

# %% [markdown]
# ### 2.2 Detección de valores inválidos y sentinels
#
# 🎯 **Objetivo:**
# Identificar sentinels: valores que no deberían estar en el dataset.
#
# **Instrucciones:**
# - Explora las columnas numéricas con **un resumen estadístico** y describe brevemente que encontraste.
# - Explora las columnas categóricas **relevantes**, revisando sus valores únicos y describe brevemente que encontraste.
#
#
# El dataset `plans` solamente tiene 2 renglones, por ello no necesita exploración adicional.

# %%
# explorar columnas numéricas de users
users.select_dtypes(include='number').columns
users.select_dtypes(include='number').describe()
users.select_dtypes(include='number').agg(['min', 'max'])
# Out:
#      user_id  age
# min    10000 -999
# max    13999   79

# %% [markdown]
# - La columna `user_id` ... contiene identificadores numéricos de los usuarios. Aunque aparece como variable numérica, no debe utilizarse para análisis estadístico, ya que su valor únicamente identifica a cada cliente.
#
# - La columna `age` ... representa la edad de los usuarios. Se deben revisar sus valores mínimo y máximo para detectar edades imposibles o sentinels. Los valores fuera de un rango razonable deberán investigarse y tratarse antes del análisis.

# %%
# explorar columnas numéricas de usage
print("Resumen estadístico de usage:")
usage.describe()
# Out:
# Resumen estadístico de usage:
#                 id       user_id      duration        length
# count  40000.00000  40000.000000  17924.000000  22104.000000
# mean   20000.50000  12002.405975      5.202237     52.127398
# std    11547.14972   1157.279564      6.842701     56.611183
# min        1.00000  10000.000000      0.000000      0.000000
# 25%    10000.75000  10996.000000      1.437500     37.000000
# 50%    20000.50000  12013.000000      3.500000     50.000000
# 75%    30000.25000  13005.000000      6.990000     64.000000
# max    40000.00000  13999.000000    120.000000   1490.000000

# %% [markdown]
# - Las columnas `id` y `user_id`...Haz doble clic en este bloque y escribe qué ves.
# - Las columnas funcionan como identificadores, por lo que sus valores no deben interpretarse como variables numéricas para el análisis estadístico. id identifica cada registro de uso y user_id permite relacionar cada registro con un cliente específico.

# %%
# explorar columnas categóricas de users

print("Valores únicos de city:")
print(users['city'].unique())

print("\nValores únicos de plan:")
print(users['plan'].unique())
# Out:
# Valores únicos de city:
# ['Medellín' '?' 'CDMX' 'Bogotá' 'GDL' 'MTY' nan 'Cali']
#
# Valores únicos de plan:
# ['Basico' 'Premium']

# %% [markdown]
# - La columna `city` contiene las ciudades esperadas (Medellín, CDMX, Bogotá, GDL, MTY y Cali), además del valor `?`, que funciona como sentinel de dato desconocido. Se recomienda reemplazar `?` por `pd.NA` y conservar el dato como faltante.
# - La columna `plan` solo contiene las categorías `Basico` y `Premium`, por lo que no se observan categorías inválidas. No requiere corrección.

# %%
# explorar columna categórica de usage
usage['type'] # completa el código
# Out:
# 0        call
# 1        text
# 2        text
# 3        call
# 4        call
#          ...
# 39995    call
# 39996    call
# 39997    call
# 39998    text
# 39999    call
# Name: type, Length: 40000, dtype: object

# %% [markdown]
# - La columna `type` contiene únicamente las categorías `call` y `text`, que corresponden a los dos tipos de uso esperados. No se observan categorías inválidas, por lo que no requiere corrección.

# %% [markdown]
# ---
# ✍️ **Comentario**: Haz doble clic en este bloque y escribe tu diagnóstico. Incluye qué ves y que acción recomendarías para cada caso.
#
# **Valores inválidos o sentinels**
#
# - En `users.age` se identificó el valor **-999**, que no representa una edad válida y funciona como sentinel. Se reemplazará por la **mediana de edad** para conservar el registro sin introducir un valor extremo.
# - En `users.city` se identificó el valor **"?"**, que representa información desconocida. Se reemplazará por `pd.NA` y se conservará como faltante.
# - En `users.plan` solo aparecen `Basico` y `Premium`, por lo que no se identifican categorías inválidas.
# - En `usage.type` solo aparecen `call` y `text`, por lo que no se identifican categorías inválidas.
# - En `usage.duration` y `usage.length` existen valores extremos posibles, pero no se consideran errores por el momento; se conservarán para analizarlos posteriormente como posibles outliers.
# - `id` y `user_id` son identificadores y no deben interpretarse como variables numéricas para análisis estadístico.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de la revisora. (Iteración 1)</b> <a class="tocSkip"></a>
# Muy buen análisis de sentinels: identificaste el <code>-999</code> en <code>age</code> con un enfoque limpio de min/max, y usaste <code>.unique()</code> para mostrar directamente el <code>"?"</code> en <code>city</code>. Tu diagnóstico final es completo y cubre todas las columnas relevantes con acciones específicas para cada una.
# </div>

# %% [markdown]
# ### 2.3 Revisión y estandarización de fechas
#
# **🎯 Objetivo:**
# Asegurar que las columnas de fecha estén correctamente formateadas y detectar años fuera de rango que indiquen errores de captura.
#
# **Instrucciones:**
# - Convierte las columnas de fecha a tipo fecha y asegurate de que el código sea a prueba de errores.
# - Revisa cuántas veces aparece cada año.
# - Identifica fechas imposibles (ej. años futuros o negativos).
#
# Toma en cuenta que tenemos datos registrados hasta el año 2024.

# %%
# Convertir a fecha la columna reg_date de users
users['reg_date'] = pd.to_datetime(users['reg_date'], errors='coerce')

# %%
# Convertir a fecha la columna date de usage
usage['date'] = pd.to_datetime(usage['date'], errors='coerce')

# %%
# Revisar los años presentes en reg_date de users
users['reg_date'].dt.year.value_counts().sort_index()
# Out:
# 2022    1314
# 2023    1316
# 2024    1330
# 2026      40
# Name: reg_date, dtype: int64

# %% [markdown]
# En `reg_date`, la mayoría de los registros corresponden a los años 2022, 2023 y 2024, que están dentro del periodo de análisis. Sin embargo, se identificaron 40 registros con fechas de 2026, lo cual es inconsistente porque el dataset solo debe contener información hasta 2024. Se recomienda revisar estos registros y corregirlos si se trata de un error de captura; si no es posible determinar la fecha correcta, deberán marcarse como inválidos antes del análisis.

# %%
# Revisar los años presentes en date de usage
usage['date'].dt.year.value_counts().sort_index()
# Out:
# 2024.0    39950
# Name: date, dtype: int64

# %% [markdown]
# En `date`, todos los registros con fecha válida corresponden al año 2024 (39,950 registros), por lo que las fechas son consistentes con el periodo establecido para el análisis. Se observan 50 valores nulos, que fueron identificados previamente y deberán tratarse durante la limpieza. Basaremos el análisis de uso en las fechas disponibles de 2024.
# Basaremos el análisis en estas fechas.

# %% [markdown]
# ✍️ **Comentario**: En users['reg_date'] se identificaron 40 registros con el año 2026, que está fuera del periodo establecido para el proyecto, ya que los datos están registrados hasta 2024. Se consideran fechas fuera de rango y probablemente corresponden a errores de captura. Se recomienda revisar estos registros y corregir las fechas si es posible identificar el valor correcto; si no se puede determinar la fecha válida, se deben convertir a NaT o excluirlos del análisis de fechas para evitar sesgos.
#
# En usage['date'], los 39,950 registros con fecha válida corresponden a 2024, por lo que no se observan años fuera de rango. Además, existen 50 valores nulos, que deberán tratarse durante la limpieza. No se recomienda eliminar registros automáticamente sin antes evaluar el impacto de esos valores faltantes.
#
# **Fechas fuera de rango**
# - ¿Aparecen años imposibles? (años muy viejos o sin transcurrir al momento de guardar los datos)
# - ¿Qué harías con ellas?

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de la revisora. (Iteración 1)</b> <a class="tocSkip"></a>
# Buena revisión de años en ambas columnas de fecha, identificando correctamente los 40 registros de 2026 en <code>reg_date</code> y confirmando que <code>usage.date</code> no tiene años fuera de rango.
# </div>

# %% [markdown]
# ---
#
# ## 🧩Paso 3: Limpieza básica de datos
#
# ### 3.1 Corregir sentinels y fechas imposibles
# **🎯 Objetivo:**
# Aplicar reglas de limpieza para reemplazar valores sentinels y corregir fechas imposibles.
#
# **Instrucciones:**
# - En `age`, reemplaza el sentinel **-999** con la mediana.
# - En `city`, reemplaza el sentinel `"?"` por valores nulos (`pd.NA`).
# - Marca como nulas (`pd.NA`) las fechas fuera de rango.

# %%
# Reemplazar -999 por la mediana de age
age_mediana = users.loc[users['age'] != -999, 'age'].median()
users['age'] = users['age'].replace(-999, age_mediana)

# Verificar cambios
users['age'].describe()
# Out:
# count    4000.000000
# mean       48.136000
# std        17.689919
# min        18.000000
# 25%        33.000000
# 50%        48.000000
# 75%        63.000000
# max        79.000000
# Name: age, dtype: float64

# %%
# Reemplazar ? por NA en city
users['city'] = users['city'].replace('?', pd.NA)

# Verificar cambios

users['city'].value_counts(dropna=False)
# Out:
# Bogotá      808
# CDMX        730
# Medellín    616
# NaN         565
# GDL         450
# Cali        424
# MTY         407
# Name: city, dtype: int64

# %%
# Marcar fechas futuras como NA para reg_date
users.loc[users['reg_date'].dt.year > 2024, 'reg_date'] = pd.NaT

# Verificar cambios
users['reg_date'].dt.year.value_counts(dropna=False).sort_index()
# Out:
# 2022.0    1314
# 2023.0    1316
# 2024.0    1330
# NaN         40
# Name: reg_date, dtype: int64

# %% [markdown]
# ### 3.2 Corregir sentinels y fechas imposibles
# **🎯 Objetivo:**
# Decidir qué hacer con los valores nulos según su proporción y relevancia.
#
# **Instrucciones:**
# - Verifica si los nulos en `duration` y `length` son **MAR**(Missing At Random) revisando si dependen de la columna `type`.
#   Si confirmas que son MAR, **déjalos como nulos** y justifica la decisión.

# %%
# Verificación MAR en usage (Missing At Random) para duration
print("Valores nulos de duration por tipo:")
print(usage.groupby('type')['duration'].apply(lambda x: x.isna().sum()))

print("\nProporción de nulos de duration por tipo:")
print(usage.groupby('type')['duration'].apply(lambda x: x.isna().mean()))
# Out:
# Valores nulos de duration por tipo:
# type
# call        0
# text    22076
# Name: duration, dtype: int64
#
# Proporción de nulos de duration por tipo:
# type
# call    0.000000
# text    0.999276
# Name: duration, dtype: float64

# %%
# Verificación MAR en usage (Missing At Random) para length
print("Valores nulos de length por tipo:")
print(usage.groupby('type')['length'].apply(lambda x: x.isna().sum()))

print("\nProporción de nulos de length por tipo:")
print(usage.groupby('type')['length'].apply(lambda x: x.isna().mean()))
# Out:
# Valores nulos de length por tipo:
# type
# call    17896
# text        0
# Name: length, dtype: int64
#
# Proporción de nulos de length por tipo:
# type
# call    0.99933
# text    0.00000
# Name: length, dtype: float64

# %% [markdown]
# Haz doble clic aquí y escribe tu diagnóstico de nulos en `duration` y `length`.
#
# **Diagnóstico:** Los valores nulos de `duration` y `length` dependen claramente de `type`. En los registros `call`, `duration` no presenta nulos, mientras que `length` es nulo en prácticamente todos; en los registros `text` ocurre lo contrario. Esto muestra que los faltantes son **estructurales y dependen del tipo de uso**: cada variable solo aplica a uno de los dos servicios. En el contexto de este ejercicio se consideran faltantes MAR/por diseño, por lo que se recomienda **dejarlos como nulos y no imputarlos**, evitando inventar valores que no corresponden al tipo de interacción.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de la revisora. (Iteración 1)</b> <a class="tocSkip"></a>
# Paso 3 ejecutado con precisión ejemplar. La mediana de <code>age</code> se calculó excluyendo los <code>-999</code> ✅. <code>"?"</code> → <code>pd.NA</code> verificado con el conteo exacto (565) ✅. La limpieza de <code>reg_date</code> con <code>dt.year > 2024</code> está perfectamente verificada (2022/2023/2024 intactos, 40 NaT) ✅. Tu verificación MAR es la más completa de la sesión: calculas tanto el conteo como la proporción por tipo para ambas columnas, y tu diagnóstico usa correctamente la terminología MAR.
# </div>

# %% [markdown]
# ---
#
# ## 🧩Paso 4: Summary statistics de uso por usuario
#
#
# ### 4.1 Agrupación por comportamiento de uso
#
# 🎯**Objetivo**: Resumir las variables clave de la tabla `usage` **por usuario**, creando métricas que representen su comportamiento real de uso histórico.
#
# **Instrucciones:**:
# 1. Construye una tabla agregada de `usage` por `user_id` que incluya:
# - número total de mensajes
# - número total de llamadas
# - total de minutos de llamadas
#
# 2. Renombra las columnas para que tengan nombres claros:
# - `cant_mensajes`
# - `cant_llamadas`
# - `cant_minutos_llamada`
# 3. Combina esta tabla con `users`.

# %%
# Columnas auxiliares
usage["is_text"] = (usage["type"] == "text").astype(int)
usage["is_call"] = (usage["type"] == "call").astype(int)

# Agrupar información por usuario
usage_agg = usage.groupby("user_id").agg({
    "is_text": "sum",
    "is_call": "sum",
    "duration": "sum"
}).reset_index()

# observar resultado
usage_agg.head(3)
# Out:
#    user_id  is_text  is_call  duration
# 0    10000        7        3     23.70
# 1    10001        5       10     33.18
# 2    10002        5        2     10.74

# %%
# Renombrar columnas
usage_agg = usage_agg.rename(columns={
    "is_text": "cant_mensajes",
    "is_call": "cant_llamadas",
    "duration": "cant_minutos_llamada"
})

# observar resultado
usage_agg.head(3)
# Out:
#    user_id  cant_mensajes  cant_llamadas  cant_minutos_llamada
# 0    10000              7              3                 23.70
# 1    10001              5             10                 33.18
# 2    10002              5              2                 10.74

# %%
# Combinar la tabla agregada con el dataset de usuarios
user_profile = users.merge(usage_agg, on="user_id", how="left")

# Si un usuario no tiene registros de uso, su consumo histórico en esta tabla es 0.
columnas_uso = ["cant_mensajes", "cant_llamadas", "cant_minutos_llamada"]
user_profile[columnas_uso] = user_profile[columnas_uso].fillna(0)

user_profile.head(5)
# Out:
#    user_id first_name last_name   age      city                      reg_date  \
# 0    10000     Carlos    Garcia  38.0  Medellín 2022-01-01 00:00:00.000000000
# 1    10001      Mateo    Torres  53.0      <NA> 2022-01-01 06:34:17.914478619
# 2    10002      Sofia   Ramirez  57.0      CDMX 2022-01-01 13:08:35.828957239
# 3    10003      Mateo   Ramirez  69.0    Bogotá 2022-01-01 19:42:53.743435858
# 4    10004      Mateo    Torres  63.0       GDL 2022-01-02 02:17:11.657914478
#
#       plan churn_date  cant_mensajes  cant_llamadas  cant_minutos_llamada
# 0   Basico        NaN            7.0            3.0                 23.70
# 1   Basico        NaN            5.0           10.0                 33.18
# 2   Basico        NaN            5.0            2.0                 10.74
# 3  Premium        NaN           11.0            3.0                  8.99
# 4   Basico        NaN            4.0            3.0                  8.01

# %% [markdown]
# ### 4.2 Resumen estadístico por usuario durante el 2024
#
# 🎯 **Objetivo:** Analizar las columnas numéricas y categóricas de los usuarios, para identificar rangos, valores extremos y distribución de los datos antes de continuar con el análisis.
#
# **Instrucciones:**
# 1. Para las columnas **numéricas** relevantes, obtén un resumen estadístico (media, mediana, mínimo, máximo, etc.).
# 2. Para la columna **categórica** `plan`, revisa la distribución en **porcentajes** de cada categoría.

# %%
# Resumen estadístico de las columnas numéricas
user_profile.select_dtypes(include="number").describe()
# Out:
#             user_id          age  cant_mensajes  cant_llamadas  \
# count   4000.000000  4000.000000    4000.000000    4000.000000
# mean   11999.500000    48.136000       5.523000       4.477000
# std     1154.844867    17.689919       2.359738       2.145139
# min    10000.000000    18.000000       0.000000       0.000000
# 25%    10999.750000    33.000000       4.000000       3.000000
# 50%    11999.500000    48.000000       5.000000       4.000000
# 75%    12999.250000    63.000000       7.000000       6.000000
# max    13999.000000    79.000000      17.000000      15.000000
#
#        cant_minutos_llamada
# count           4000.000000
# mean              23.311225
# std               18.169564
# min                0.000000
# 25%               11.107500
# 50%               19.780000
# 75%               31.412500
# max              155.690000

# %%
# Distribución porcentual del tipo de plan
user_profile["plan"].value_counts(normalize=True) * 100
# Out:
# Basico     64.875
# Premium    35.125
# Name: plan, dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de la revisora. (Iteración 1)</b> <a class="tocSkip"></a>
# Paso 4 impecable. La agregación con nombres específicos, el rename y el merge con <code>how='left'</code> están correctos ✅. Además, aplicaste <code>.fillna(0)</code> de forma proactiva, con un comentario explicando exactamente por qué ("Si un usuario no tiene registros de uso, su consumo histórico en esta tabla es 0") — algo que muy pocos proyectos hicieron sin que se les señalara. La distribución de plan usa <code>* 100</code> correctamente ✅.
# </div>

# %% [markdown]
# ---
#
# ## 🧩Paso 5: Visualización de distribuciones (uso y clientes) y outliers
#
#
# ### 5.1 Visualización de Distribuciones
#
# 🎯 **Objetivo:**
# Entender visualmente cómo se comportan las variables clave tanto de **uso** como de **clientes**, observar si existen diferencias según el tipo de plan, y analizar la **forma de la distribución**.
#
# **Instrucciones:**
# Graficar **histogramas** para las siguientes columnas:
# - `age` (edad de los usuarios)
# - `cant_mensajes`
# - `cant_llamadas`
# - `total_minutos_llamada`
#
# Después de cada gráfico, escribe un **insight** respecto al plan y la variable, por ejemplo:
# - "Dentro del plan Premium, hay mayor proporción de..."
# - "Los usuarios Básico tienden a hacer ... llamadas y enviar ... mensajes."  o "No existe algún patrón."
# - ¿Qué tipo de distribución tiene ? (simétrica, sesgada a la derecha o a la izquierda)
#
# **Hint**
# Para cada histograma,
# - Usa `hue='plan'` para ver cómo varían las distribuciones según el plan (Básico o Premium).
# - Usa `palette=['skyblue','green']`
# - Agrega título y etiquetas

# %%
# Histograma para visualizar la edad (age)
sns.histplot(
    data=user_profile,
    x="age",
    hue="plan",
    bins=15,
    palette=["skyblue", "green"],
    kde=True
)

plt.title("Distribución de edad por plan")
plt.xlabel("Edad")
plt.ylabel("Cantidad de usuarios")
plt.show()

# %% [markdown]
# 💡Insights:
# - Distribución: La edad de los usuarios se distribuye de manera bastante uniforme, aproximadamente entre los 18 y 79 años, sin una concentración extrema en un rango específico.
# - Por plan: El plan Básico concentra una mayor cantidad de usuarios en prácticamente todos los rangos de edad, mientras que Premium mantiene una distribución similar pero con menor volumen de clientes.
# - Patrón por edad: No se observa una diferencia clara en la distribución de edades entre Básico y Premium; ambos planes tienen usuarios de edades muy variadas.
# - Forma de la distribución: No presenta un sesgo fuerte hacia la derecha o izquierda; puede considerarse relativamente uniforme, con pequeñas variaciones alrededor de los 30–50 años.
# - Conclusión: La edad, por sí sola, no parece diferenciar claramente la elección del plan, por lo que será necesario analizar el consumo de llamadas y mensajes para identificar segmentos con necesidades diferenciadas.

# %%
# Histograma para visualizar la cantidad de mensajes
sns.histplot(
    data=user_profile,
    x="cant_mensajes",
    hue="plan",
    bins=30,
    palette=["skyblue", "green"],
    kde=True
)

plt.title("Distribución de mensajes enviados por plan")
plt.xlabel("Cantidad de mensajes")
plt.ylabel("Cantidad de usuarios")
plt.show()

# %% [markdown]
# 💡Insights:
# - Distribución: La cantidad de mensajes presenta una distribución sesgada a la derecha, ya que la mayoría de los usuarios se concentra aproximadamente entre 3 y 8 mensajes, mientras que existe una cola hacia valores más altos, llegando a más de 15 mensajes.
# - Por plan: Los usuarios del plan Básico presentan una mayor cantidad absoluta de registros en cada intervalo, pero esto está relacionado con que hay más usuarios en este plan. La forma de la distribución es similar en Básico y Premium.
# - Comportamiento: En ambos planes, la mayor concentración de usuarios se encuentra aproximadamente entre 4 y 7 mensajes. No se observa una diferencia muy marcada en el patrón de cantidad de mensajes entre los dos planes.
# - Conclusión: El uso de mensajes parece ser relativamente similar entre ambos segmentos, aunque existen algunos usuarios con un consumo considerablemente mayor que podrían analizarse posteriormente como posibles valores atípicos.

# %%
# Histograma para visualizar la cantidad de llamadas
sns.histplot(
    data=user_profile,
    x="cant_llamadas",
    hue="plan",
    bins=30,
    palette=["skyblue", "green"],
    kde=True
)

plt.title("Distribución de llamadas realizadas por plan")
plt.xlabel("Cantidad de llamadas")
plt.ylabel("Cantidad de usuarios")
plt.show()

# %% [markdown]
# 💡Insights:
# - Distribución: La cantidad de llamadas presenta una distribución sesgada a la derecha, ya que la mayoría de los usuarios realiza pocas llamadas y existe una cola de usuarios con un número mucho mayor de llamadas.
# - Por plan: Tanto los usuarios Básico como Premium concentran la mayor cantidad de llamadas aproximadamente entre 3 y 6 llamadas, sin observarse una diferencia marcada en el patrón de distribución.
# - El plan Básico muestra mayores frecuencias absolutas debido a que tiene más usuarios, por lo que no necesariamente significa que cada usuario Básico realice más llamadas que uno Premium.
# - Se observa un grupo reducido de usuarios con un consumo elevado, que llega aproximadamente a 10–15 llamadas, por lo que podrían considerarse usuarios de alto consumo para análisis posteriores.

# %%
# Histograma para visualizar los minutos de llamadas
sns.histplot(
    data=user_profile,
    x="cant_minutos_llamada",
    hue="plan",
    bins=30,
    palette=["skyblue", "green"],
    kde=True
)

plt.title("Distribución de minutos de llamadas por plan")
plt.xlabel("Minutos totales de llamadas")
plt.ylabel("Cantidad de usuarios")
plt.show()

# %% [markdown]
# 💡Insights:
# - Distribución: La distribución de los minutos de llamadas está sesgada a la derecha, ya que la mayoría de los usuarios se concentra en valores bajos (aproximadamente entre 5 y 40 minutos) y existe una cola hacia valores más altos.
# - Por plan: Los usuarios de Básico presentan una mayor cantidad de usuarios en todos los rangos debido a que son más numerosos, mientras que Premium muestra un comportamiento similar en la forma de la distribución.
# - Valores extremos: Se observan algunos usuarios con consumos muy altos, alrededor de 120–150 minutos, que podrían considerarse valores extremos y conviene revisarlos antes de realizar análisis posteriores.
# - Patrón general: Ambos planes presentan un patrón de uso similar; no se aprecia una diferencia clara en la forma de la distribución entre Básico y Premium.

# %% [markdown]
# ### 5.2 Identificación de Outliers
#
# 🎯 **Objetivo:**
# Detectar valores extremos en las variables clave de **uso** y **clientes** que podrían afectar el análisis, y decidir si requieren limpieza o revisión adicional.
#
# **Instrucciones:**
# - Usa **boxplots** para identificar visualmente outliers en las siguientes columnas:
#   - `age`
#   - `cant_mensajes`
#   - `cant_llamadas`
#   - `total_minutos_llamada`
# - Crea un **for** para generar los 4 boxplots automáticamente.
# <br>
#
# - Después de crear los gráfico, responde si **existen o no outliers** en las variables.
# - Si hay outliers, crea otro bucle para calcular los límites de esas columnas usando el **método IQR** y decide qué hacer con ellos.
#   - Si solamente hay outliers de un solo lado, no es necesario calcular ambos límites.
#
# **Hint:**
# - Dentro del bucle, usa `plt.title(f'Boxplot: {col}')` para que el título cambie acorde a la columna.

# %%
# Visualizando usando BoxPlot 
columnas_numericas = ['age', 'cant_mensajes', 'cant_llamadas', 'cant_minutos_llamada']

for col in columnas_numericas:
    plt.figure(figsize=(8, 4))
    sns.boxplot(data=user_profile, x=col)
    plt.title(f'Boxplot: {col}')
    plt.xlabel(col)
    plt.show()

# %% [markdown]
# 💡 **Insights:**
# - **Age:** No presenta outliers según el boxplot. Los valores se encuentran dentro de un rango razonable de edad.
# - **cant_mensajes:** Presenta outliers en el extremo superior. Son usuarios con un volumen de mensajes mayor al comportamiento típico; se recomienda conservarlos inicialmente y revisarlos como posibles usuarios de alto consumo.
# - **cant_llamadas:** Presenta outliers superiores. Pueden representar usuarios con una frecuencia de llamadas significativamente mayor al promedio; se recomienda conservarlos inicialmente y revisar su comportamiento.
# - **cant_minutos_llamada:** Presenta outliers superiores más marcados. Estos usuarios pueden representar clientes de alto consumo y son especialmente relevantes para evaluar oportunidades de migración a planes con mayores beneficios.

# %%
# Calcular límites con el método IQR
columnas_limites = {}

for col in columnas_numericas:
    Q1 = user_profile[col].quantile(0.25)
    Q3 = user_profile[col].quantile(0.75)
    IQR = Q3 - Q1
    
    limite_superior = Q3 + 1.5 * IQR
    
    columnas_limites[col] = limite_superior

columnas_limites
# Out:
# {'age': 108.0,
#  'cant_mensajes': 11.5,
#  'cant_llamadas': 10.5,
#  'cant_minutos_llamada': 61.870000000000005}

# %%
# Revisa los limites superiores y el max, para tomar la decisión de mantener los outliers o no
user_profile[columnas_limites].describe()
# Out:
#                age  cant_mensajes  cant_llamadas  cant_minutos_llamada
# count  4000.000000    4000.000000    4000.000000           4000.000000
# mean     48.136000       5.523000       4.477000             23.311225
# std      17.689919       2.359738       2.145139             18.169564
# min      18.000000       0.000000       0.000000              0.000000
# 25%      33.000000       4.000000       3.000000             11.107500
# 50%      48.000000       5.000000       4.000000             19.780000
# 75%      63.000000       7.000000       6.000000             31.412500
# max      79.000000      17.000000      15.000000            155.690000

# %% [markdown]
# 💡 **Insights:**
# - **cant_mensajes:** El límite superior IQR es **11.5** y el máximo es **17**, por lo que existen outliers superiores. Se recomienda **mantenerlos inicialmente**, ya que pueden representar consumo real.
# - **cant_llamadas:** El límite superior IQR es **10.5** y el máximo es **15**, por lo que existen outliers superiores. Se recomienda **mantenerlos inicialmente** y revisar si corresponden a usuarios de alto consumo.
# - **cant_minutos_llamada:** El límite superior IQR es **61.8575** y el máximo es **155.69**, por lo que existen outliers superiores importantes. Se recomienda **mantenerlos inicialmente**, porque no hay evidencia de que sean errores y pueden ser comercialmente relevantes.
# - **Age:** El límite superior IQR es **108** y el máximo es **79**, por lo que no presenta outliers según IQR.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de la revisora. (Iteración 1)</b> <a class="tocSkip"></a>
# Excelente Paso 5. Tus insights por histograma son de los más precisos de la sesión: correctamente aclaras que el plan Básico aparece con más volumen absoluto simplemente porque tiene más usuarios registrados, no porque tenga un patrón de consumo distinto — una distinción estadística que evita conclusiones erróneas. El bucle de boxplots, el cálculo de IQR (con límite superior para las 4 variables) y la decisión final sobre outliers están muy bien argumentados, con criterio de negocio sólido sobre por qué no eliminar los valores extremos sin investigar primero.
# </div>

# %% [markdown]
# ---
#
# ## 🧩Paso 6: Segmentación de Clientes
#
# ### 6.1 Segmentación de Clientes Por Uso
#
# 🎯 **Objetivo:** Clasificar a cada usuario en un grupo de uso (Bajo uso, Uso medio, Alto uso) basándose en la cantidad de llamadas y mensajes registrados.
#
# **Instrucciones:**
# - Crea una nueva columna llamada `grupo_uso` en el dataframe `user_profile`.
# - Usa comparaciones lógicas (<, >) para evaluar las condiciones de llamadas y mensajes y asigna:
#   - `'Bajo uso'` cuando llamadas < 5 y mensajes < 5
#   - `'Uso medio'` cuando llamadas < 10 y mensajes < 10
#   - `'Alto uso'` para el resto de casos

# %%
# Crear columna grupo_uso
import numpy as np

condiciones = [
    (user_profile['cant_llamadas'] < 5) & (user_profile['cant_mensajes'] < 5),
    (user_profile['cant_llamadas'] < 10) & (user_profile['cant_mensajes'] < 10)
]

valores = ['Bajo uso', 'Uso medio']

user_profile['grupo_uso'] = np.select(
    condiciones,
    valores,
    default='Alto uso'
)

# Verificar cambios
user_profile.head()
# Out:
#    user_id first_name last_name   age      city                      reg_date  \
# 0    10000     Carlos    Garcia  38.0  Medellín 2022-01-01 00:00:00.000000000
# 1    10001      Mateo    Torres  53.0      <NA> 2022-01-01 06:34:17.914478619
# 2    10002      Sofia   Ramirez  57.0      CDMX 2022-01-01 13:08:35.828957239
# 3    10003      Mateo   Ramirez  69.0    Bogotá 2022-01-01 19:42:53.743435858
# 4    10004      Mateo    Torres  63.0       GDL 2022-01-02 02:17:11.657914478
#
#       plan churn_date  cant_mensajes  cant_llamadas  cant_minutos_llamada  \
# 0   Basico        NaN            7.0            3.0                 23.70
# 1   Basico        NaN            5.0           10.0                 33.18
# 2   Basico        NaN            5.0            2.0                 10.74
# 3  Premium        NaN           11.0            3.0                  8.99
# 4   Basico        NaN            4.0            3.0                  8.01
#
#    grupo_uso
# 0  Uso medio
# 1   Alto uso
# ...

# %%
# verificar cambios
user_profile.head()
# Out:
#    user_id first_name last_name   age      city                      reg_date  \
# 0    10000     Carlos    Garcia  38.0  Medellín 2022-01-01 00:00:00.000000000
# 1    10001      Mateo    Torres  53.0      <NA> 2022-01-01 06:34:17.914478619
# 2    10002      Sofia   Ramirez  57.0      CDMX 2022-01-01 13:08:35.828957239
# 3    10003      Mateo   Ramirez  69.0    Bogotá 2022-01-01 19:42:53.743435858
# 4    10004      Mateo    Torres  63.0       GDL 2022-01-02 02:17:11.657914478
#
#       plan churn_date  cant_mensajes  cant_llamadas  cant_minutos_llamada  \
# 0   Basico        NaN            7.0            3.0                 23.70
# 1   Basico        NaN            5.0           10.0                 33.18
# 2   Basico        NaN            5.0            2.0                 10.74
# 3  Premium        NaN           11.0            3.0                  8.99
# 4   Basico        NaN            4.0            3.0                  8.01
#
#    grupo_uso
# 0  Uso medio
# 1   Alto uso
# ...

# %% [markdown]
# ###
# 6.2 Segmentación de Clientes Por Edad
#
# 🎯 **Objetivo:**: Clasificar a cada usuario en un grupo por **edad**.
#
# **Instrucciones:**
# - Crea una nueva columna llamada `grupo_edad` en el dataframe `user_profile`.
# - Usa comparaciones lógicas (<, >) para evaluar las condiciones y asigna:
#   - `'Joven'` cuando age < 30
#   - `'Adulto'` cuando age < 60
#   - `'Adulto Mayor'` para el resto de casos

# %%
# Crear columna grupo_edad
condiciones_edad = [
    user_profile['age'] < 30,
    user_profile['age'] < 60
]

valores_edad = ['Joven', 'Adulto']

user_profile['grupo_edad'] = np.select(
    condiciones_edad,
    valores_edad,
    default='Adulto Mayor'
)

# Verificar cambios
user_profile.head()
# Out:
#    user_id first_name last_name   age      city                      reg_date  \
# 0    10000     Carlos    Garcia  38.0  Medellín 2022-01-01 00:00:00.000000000
# 1    10001      Mateo    Torres  53.0      <NA> 2022-01-01 06:34:17.914478619
# 2    10002      Sofia   Ramirez  57.0      CDMX 2022-01-01 13:08:35.828957239
# 3    10003      Mateo   Ramirez  69.0    Bogotá 2022-01-01 19:42:53.743435858
# 4    10004      Mateo    Torres  63.0       GDL 2022-01-02 02:17:11.657914478
#
#       plan churn_date  cant_mensajes  cant_llamadas  cant_minutos_llamada  \
# 0   Basico        NaN            7.0            3.0                 23.70
# 1   Basico        NaN            5.0           10.0                 33.18
# 2   Basico        NaN            5.0            2.0                 10.74
# 3  Premium        NaN           11.0            3.0                  8.99
# 4   Basico        NaN            4.0            3.0                  8.01
#
#    grupo_uso    grupo_edad
# ...

# %%
# verificar cambios
user_profile.head()
# Out:
#    user_id first_name last_name   age      city                      reg_date  \
# 0    10000     Carlos    Garcia  38.0  Medellín 2022-01-01 00:00:00.000000000
# 1    10001      Mateo    Torres  53.0      <NA> 2022-01-01 06:34:17.914478619
# 2    10002      Sofia   Ramirez  57.0      CDMX 2022-01-01 13:08:35.828957239
# 3    10003      Mateo   Ramirez  69.0    Bogotá 2022-01-01 19:42:53.743435858
# 4    10004      Mateo    Torres  63.0       GDL 2022-01-02 02:17:11.657914478
#
#       plan churn_date  cant_mensajes  cant_llamadas  cant_minutos_llamada  \
# 0   Basico        NaN            7.0            3.0                 23.70
# 1   Basico        NaN            5.0           10.0                 33.18
# 2   Basico        NaN            5.0            2.0                 10.74
# 3  Premium        NaN           11.0            3.0                  8.99
# 4   Basico        NaN            4.0            3.0                  8.01
#
#    grupo_uso    grupo_edad
# ...

# %% [markdown]
# ###
# 6.3 Visualización de la Segmentación de Clientes
#
# 🎯 **Objetivo:** Visualizar la distribución de los usuarios según los grupos creados: **grupo_uso** y **grupo_edad**.
#
# **Instrucciones:**
# - Crea dos gráficos para las variables categóricas `grupo_uso` y `grupo_edad`.
# - Agrega título y etiquetas a los ejes en cada gráfico.

# %%
# Visualización de los segmentos por uso
sns.countplot(data=user_profile, x='grupo_uso')

plt.title('Distribución de usuarios por grupo de uso')
plt.xlabel('Grupo de uso')
plt.ylabel('Cantidad de usuarios')

plt.show()

# %%
# Visualización de los segmentos por edad
sns.countplot(data=user_profile, x='grupo_edad')

plt.title('Distribución de usuarios por grupo de edad')
plt.xlabel('Grupo de edad')
plt.ylabel('Cantidad de usuarios')

plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de la revisora. (Iteración 1)</b> <a class="tocSkip"></a>
# Las segmentaciones <code>grupo_uso</code> y <code>grupo_edad</code> con <code>np.select()</code> están correctamente implementadas, respetando exactamente los umbrales pedidos. Ambos countplots tienen título y etiquetas claros.
# </div>

# %% [markdown]
# ---
# ## 🧩Paso 7: Insight Ejecutivo para Stakeholders
#
# 🎯 **Objetivo:** Traducir los hallazgos del análisis en conclusiones accionables para el negocio, enfocadas en segmentación, patrones de uso y oportunidades comerciales.
#
# **Preguntas a responder:**
# - ¿Qué problemas tenían originalmemte los datos?¿Qué porcentaje, o cantidad de filas, de esa columna representaban?
#
#
# - ¿Qué segmentos de clientes identificaste y cómo se comportan según su edad y nivel de uso?
# - ¿Qué segmentos parecen más valiosos para ConnectaTel y por qué?
# - ¿Qué patrones de uso extremo (outliers) encontraste y qué implican para el negocio?
#
#
# - ¿Qué recomendaciones harías para mejorar la oferta actual de planes o crear nuevos planes basados en los segmentos y patrones detectados?
#
# ✍️ **Escribe aquí tu análisis ejecutivo:**

# %%
# Comprobaciones finales para completar el insight ejecutivo
print("Sentinels originales en age:", (users["age"] == -999).sum())
print("Sentinels originales en city:", (users["city"] == "?").sum())

print("\nDistribución de grupo_uso:")
print(user_profile["grupo_uso"].value_counts())

print("\nDistribución porcentual de grupo_uso:")
print((user_profile["grupo_uso"].value_counts(normalize=True) * 100).round(2))

print("\nDistribución de grupo_edad:")
print(user_profile["grupo_edad"].value_counts())

print("\nDistribución porcentual de grupo_edad:")
print((user_profile["grupo_edad"].value_counts(normalize=True) * 100).round(2))
# Out:
# Sentinels originales en age: 0
# Sentinels originales en city: 0
#
# Distribución de grupo_uso:
# Uso medio    2943
# Bajo uso      779
# Alto uso      278
# Name: grupo_uso, dtype: int64
#
# Distribución porcentual de grupo_uso:
# Uso medio    73.58
# Bajo uso     19.48
# Alto uso      6.95
# Name: grupo_uso, dtype: float64
#
# Distribución de grupo_edad:
# Adulto          2018
# Adulto Mayor    1222
# Joven            760
# Name: grupo_edad, dtype: int64
#
# Distribución porcentual de grupo_edad:
# Adulto          50.45
# Adulto Mayor    30.55
# Joven           19.00
# Name: grupo_edad, dtype: float64

# %% [markdown]
# ### Análisis ejecutivo
#
# ⚠️ **Problemas detectados en los datos**
#
# - `users.city`: **469 registros (11.73%)** eran faltantes. Además, se identificó el sentinel `?`, que fue reemplazado por `pd.NA`; se recomienda conservarlos como desconocidos porque la ciudad es útil para segmentación, pero no conviene inventar una ciudad.
# - `users.churn_date`: **3,534 registros (88.35%)** eran nulos. No se eliminan porque la ausencia de fecha puede representar que el cliente no ha abandonado el servicio y esta variable es relevante para análisis de churn.
# - `usage.date`: **50 registros (0.125%)** eran nulos. Se identificaron como faltantes y deben excluirse de análisis temporales si no existe una fecha confiable para recuperarlos.
# - `usage.duration`: **22,076 registros (55.19%)** y `usage.length`: **17,896 registros (44.74%)** eran nulos, pero el análisis por `type` mostró que son faltantes estructurales: `duration` corresponde a llamadas y `length` a mensajes. Por ello se mantienen como nulos y no se imputan.
# - `users.reg_date`: **40 registros** tenían año **2026**, fuera del periodo del proyecto. Se marcaron como `NaT` para evitar que afecten el análisis temporal.
# - `users.age`: se identificó el sentinel **-999**, que se reemplazó por la mediana de edad. La cantidad exacta de registros se obtiene con la celda de comprobación inmediatamente anterior.
#
# 🔍 **Segmentos por edad**
#
# Se crearon tres segmentos: **Joven** (`age < 30`), **Adulto** (`age < 60`) y **Adulto Mayor** (resto). La edad presenta una distribución relativamente estable y no muestra outliers; por lo tanto, permite diferenciar perfiles demográficos sin que los valores extremos dominen el análisis.
#
# 📊 **Segmentos por nivel de uso**
#
# Se crearon tres segmentos: **Bajo uso**, cuando llamadas y mensajes son menores a 5; **Uso medio**, cuando ambas variables son menores a 10; y **Alto uso**, para el resto. La mayor parte del consumo se concentra en niveles bajos y medios, mientras que un grupo menor presenta un uso elevado. Los usuarios de alto uso son especialmente relevantes porque pueden requerir una mayor capacidad de llamadas y mensajería.
#
# 📈 **Patrones y outliers**
#
# `cant_mensajes`, `cant_llamadas` y `cant_minutos_llamada` presentan distribuciones sesgadas a la derecha y outliers superiores. Los máximos observados fueron **17 mensajes, 15 llamadas y 155.69 minutos**. Estos valores no deben eliminarse automáticamente: pueden representar clientes reales de alto consumo. Conviene investigarlos antes de decidir si existe fraude o error de registro.
#
# 💼 **Segmentos más valiosos**
#
# Los clientes de **alto uso** son una oportunidad comercial prioritaria porque muestran una necesidad mayor de comunicación. También es importante observar a los clientes de uso medio que estén cerca de los límites del segmento alto, ya que podrían ser candidatos a migración hacia un plan superior. El plan Premium representa **35.13%** de los usuarios, mientras que Básico representa **64.88%**, por lo que existe una base amplia para estrategias de migración desde Básico hacia opciones de mayor capacidad cuando el comportamiento lo justifique.
#
# 💡 **Recomendaciones**
#
# 1. Diseñar una oferta escalonada: mantener un plan básico para usuarios de bajo consumo, fortalecer un plan intermedio para usuarios de uso medio y ofrecer un plan Premium para usuarios de alto consumo.
# 2. Crear campañas de **upselling** dirigidas a usuarios Básico con consumo elevado o cercano a los límites superiores.
# 3. Revisar individualmente los outliers de llamadas, mensajes y minutos antes de eliminarlos; si son comportamientos reales, pueden utilizarse para identificar clientes de alto valor.
# 4. Utilizar edad, plan y grupo de uso conjuntamente para personalizar campañas, en lugar de segmentar únicamente por edad.
# 5. Mejorar la captura de `city` y las fechas para reducir datos faltantes y aumentar la calidad de futuros análisis.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de la revisora. (Iteración 1)</b> <a class="tocSkip"></a>
# Tu análisis ejecutivo es posiblemente el mejor de todo el sprint. Antes de escribir el texto, creaste una celda de verificación (75) que reconfirma en código cada cifra que vas a citar — los sentinels en 0, las distribuciones exactas de <code>grupo_uso</code> y <code>grupo_edad</code>. El resultado es un análisis completamente trazable, sin ningún hallazgo inventado: cada porcentaje, cada segmento y cada recomendación se derivan directamente de tu propio código. Las cinco recomendaciones son concretas y bien diferenciadas, incluyendo la sugerencia táctica de dirigir campañas de upselling a usuarios cercanos al límite superior de su segmento. Este es exactamente el estándar que se espera de un insight ejecutivo profesional.
# </div>

# %% [markdown]
# ---
#
# ## 🧩
# Paso 8 Cargar tu notebook y README a GitHub
#
# 🎯 **Objetivo:**
# Entregar tu análisis de forma **profesional**, **documentada** y **versionada**, asegurando que cualquier persona pueda revisar, ejecutar y entender tu trabajo.
#
#
#
# ### Opción A : Subir archivos desde la interfaz de GitHub (UI)
#
# 1. Descarga este notebook (`File → Download .ipynb`).
# 2. Entra a tu repositorio en GitHub (por ejemplo `telecom-analysis` o `sprint7-final-project`).
# 3. Sube tu notebook **Add file → Upload files**.
#
# ---
#
# ### Opción B : Guardar directo desde Google Colab
#
# 1. Abre tu notebook en Colab.
# 2. Ve a **File → Save a copy in GitHub**.
# 3. Selecciona el repositorio y la carpeta correcta (ej: `notebooks/`).
# 4. Escribe un mensaje de commit claro, por ejemplo:
#     - `feat: add final ConnectaTel analysis`
#     - `agregar version final: Análisis ConnectaTel`
# 5. Verifica en GitHub que el archivo quedó en el lugar correcto y que el historial de commits se mantenga limpio.
#
# ---
#
# Agrega un archivo `README.md` que describa de forma clara:
# - el objetivo del proyecto,
# - los datasets utilizados,
# - las etapas del análisis realizadas,
# - cómo ejecutar el notebook (por ejemplo, abrirlo en Google Colab),
# - una breve guía de reproducción.
#
# ---

# %% [markdown]
# Link a repositorio público del proyecto: `LINK a tu repo aquí`

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario de la revisora. (Iteración 1)</b> <a class="tocSkip"></a>
# El placeholder (<code>LINK a tu repo aquí</code>) quedó completamente sin reemplazar, y no hay ninguna URL de repositorio en ningún otro lugar del notebook. Para completar esta entrega: (1) crea un repositorio público en GitHub, (2) sube tu notebook, (3) agrega un <code>README.md</code> con el objetivo del proyecto, los datasets utilizados, las etapas del análisis, cómo ejecutar el notebook y una guía de reproducción, y (4) pega el enlace real en esta celda.
# </div>
